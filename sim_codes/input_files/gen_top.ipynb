# %%
import random
N=2676
n=2676
with open('DLD_chr10_top.txt', 'w') as f:
    for ii in range(int(N/n)):
        f.write('{} {} 0\n'.format(ii*n,(ii+1)*n-1))

# with open('allA_seq.txt', 'w') as f:
#     for ii in range(N):
#         f.write('{} A\n'.format(ii+1))
        # if random.random()<0.5:
        #     f.write('{} A\n'.format(ii+1))
        # else:
        #     f.write('{} B\n'.format(ii+1))

# %%
with open('seq_chr10.txt','w') as fout:
    fin=open('chr10_beads.txt','r')
    for line in fin:
        row=line.split()
        if 'A' in row[1] and 'N' not in row[1]: fout.write('{} {}\n'.format(row[0],'A'))
        elif 'B' in row[1]: fout.write('{} {}\n'.format(row[0],'B'))
        elif 'N' in row[1]: fout.write('{} {}\n'.format(row[0],'C'))
        
        print(line)
# Out:
# 1 NA
#
# 2 NA
#
# 3 B1
#
# 4 B1
#
# 5 B1
#
# 6 B1
#
# 7 B1
#
# 8 B1
#
# 9 B1
#
# 10 B1
#
# 11 B1
#
# 12 B1
#
# 13 B1
#
# 14 B1
#
# 15 B1
#
# 16 B1
#
# 17 B1
#
# 18 B1
#
# 19 A1
#
# 20 A1
#
# 21 A1
#
# 22 A1
#
# 23 B1
#
# 24 B1
#
# 25 B1
#
# 26 B1
#
# 27 B1
#
# 28 B1
#
# 29 B1
#
# 30 B1
#
# 31 B1
#
# 32 B1
#
# 33 B1
#
# 34 B1
#
# 35 B1
#
# 36 B1
#
# 37 B2
#
# 38 B2
#
# 39 B2
#
# 40 B2
#
# 41 B2
#
# 42 B2
#
# 43 B2
#
# 44 B2
#
# 45 B2
#
# 46 B2
#
# 47 B2
#
# 48 B2
#
# 49 B2
#
# 50 B2
#
# 51 B2
#
# 52 B2
#
# 53 B2
#
# 54 B2
#
# 55 B2
#
# 56 B2
#
# 57 B2
#
# 58 B2
#
# 59 B2
#
# 60 B2
#
# 61 B1
#
# 62 B1
#
# 63 A2
#
# 64 A2
#
# 65 B1
#
# 66 B1
#
# 67 B2
#
# 68 B2
#
# 69 B2
#
# 70 B2
#
# 71 B1
#
# 72 B1
#
# 73 B2
#
# 74 B2
#
# 75 B1
#
# 76 B1
#
# 77 A2
#
# 78 A2
#
# 79 A2
#
# 80 A2
#
# 81 A2
#
# 82 A2
#
# 83 B1
#
# 84 B1
#
# 85 B2
#
# 86 B2
#
# 87 B2
#
# 88 B2
#
# 89 B2
#
# 90 B2
#
# 91 B2
#
# 92 B2
#
# 93 B2
#
# 94 B2
#
# 95 B2
#
# 96 B2
#
# 97 B2
#
# 98 B2
#
# 99 B2
#
# 100 B2
#
# ...

# %%
tab = pd.read_csv('type_table.csv', sep=None, engine='python')

# %%
print(tab)
# Out:
#    A    B
# 0 -1 -1.0
# 1 -1 -1.0

# %%
header_types = list(tab.columns.values)
print(header_types)
# Out:
# ['A', 'B']

# %%
lambdas = np.triu(tab.values) + np.triu(tab.values, k=1).T
lambdas = list(np.ravel(lambdas))
print(lambdas)
# Out:
# [-1.0, -1.0, -1.0, -1.0]

# %%
f=open('chr_seq_2.txt','w')
for line in open('chr_seq2.txt'):
    f.write('{}\n'.format(line[:-2]))
f.close()
