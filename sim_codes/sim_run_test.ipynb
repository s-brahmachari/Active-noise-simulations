# %%
# from OpenMiChroM.ChromDynamics import MiChroM
# from openmmtools import integrators
# from simtk import unit
# from Custom_integrators import CustomBrownianIntegrator
# import Custom_Bonds
import numpy as np
# import pandas as pd
import ActivePolymer
# from mpl_toolkits.mplot3d import Axes3D
# import matplotlib.colors as colors
# from matplotlib.animation import FuncAnimation
# import matplotlib.pyplot as plt
# from matplotlib import rcParams as rc

# %%
sim=ActivePolymer.ActivePolymer(name='test', time_step=0.001, collision_rate=0.1, temperature=150, 
        active_corr_time=100.0, activity_amplitude=1.0,
        outpath='test_out/', init_struct=None, seq_file='input_files/chr_seq_AB.txt',)
# Out:
#     ***************************************************************************************
#      **** **** *** *** *** *** *** *** OpenMiChroM-1.0.2 *** *** *** *** *** *** **** ****
#
#          OpenMiChroM is a Python library for performing chromatin dynamics simulations.
#                             OpenMiChroM uses the OpenMM Python API,
#                 employing the MiChroM (Minimal Chromatin Model) energy function.
#       The chromatin dynamics simulations generate an ensemble of 3D chromosomal structures
#       that are consistent with experimental Hi-C maps, also allows simulations of a single
#                  or multiple chromosome chain using High-Performance Computing
#                             in different platforms (GPUs and CPUs).
#          OpenMiChroM documentation is available at https://open-michrom.readthedocs.io
#
#          OpenMiChroM is described in: Oliveira Junior, A. B & Contessoto, V, G et. al.
#       A Scalable Computational Approach for Simulating Complexes of Multiple Chromosomes.
#                   Journal of Molecular Biology. doi:10.1016/j.jmb.2020.10.034.
#                                               and
#                                  Oliveira Junior, A. B. et al.
#      Chromosome Modeling on Downsampled Hi-C Maps Enhances the Compartmentalization Signal.
#                         J. Phys. Chem. B, doi:10.1021/acs.jpcb.1c04174.
#
#                     Copyright (c) 2021, The OpenMiChroM development team at
#                                         Rice University
#     ***************************************************************************************
#
#         ==================================
#         ActivePolymer Simulation now set up.
#         Loaded sequence file: input_files/chr_seq_AB.txt
#         Loaded initial structure: default spiral spring
#         Active amplitude: 1.0
#         Active correlation time: 100.0
#         Total number of active particles: 135
#         ==================================

# %%
ActivePolymer.addRadialConfinement(sim, R0=10, method='FlatBottomHarmonic', kr=50)
ActivePolymer.addHarmonicBonds(sim,top_file='input_files/chr_top.txt', kb=10.0, d=1.0, bend_stiffness=True, ka=2.0)
ActivePolymer.addSelfAvoidance(sim,)

for jj,val in enumerate(np.loadtxt('input_files/chr_top.txt', dtype=int, ndmin=2)):
    ActivePolymer.addLengthwiseCompaction(sim, chain=(val[0],val[1],jj))

ActivePolymer.addCustomTypes(sim,mu=3.,rc=2.,TypesTable='input_files/type_table.csv')
# Out:
# -------
# Implementing Flat-Bottom Harmonic confinement:
# Radius: 10.00
# Volume fraction: 0.062
# Stiffness: 50.00
#
# -------
# Adding harmonic bonds according to topology defined in input_files/chr_top.txt
# Number of polymer segments: 1
#
# Adding bending stiffness ...  [0, 1, 2]
# [1, 2, 3]
# [2, 3, 4]
# [3, 4, 5]
# [4, 5, 6]
# [5, 6, 7]
# [6, 7, 8]
# [7, 8, 9]
# [8, 9, 10]
# [9, 10, 11]
# [10, 11, 12]
# [11, 12, 13]
# [12, 13, 14]
# [13, 14, 15]
# [14, 15, 16]
# [15, 16, 17]
# [16, 17, 18]
# [17, 18, 19]
# [18, 19, 20]
# [19, 20, 21]
# [20, 21, 22]
# [21, 22, 23]
# [22, 23, 24]
# [23, 24, 25]
# [24, 25, 26]
# [25, 26, 27]
# [26, 27, 28]
# [27, 28, 29]
# [28, 29, 30]
# [29, 30, 31]
# [30, 31, 32]
# [31, 32, 33]
# [32, 33, 34]
# [33, 34, 35]
# [34, 35, 36]
# [35, 36, 37]
# [36, 37, 38]
# [37, 38, 39]
# [38, 39, 40]
# [39, 40, 41]
# [40, 41, 42]
# [41, 42, 43]
# [42, 43, 44]
# [43, 44, 45]
# [44, 45, 46]
# [45, 46, 47]
# [46, 47, 48]
# [47, 48, 49]
# [48, 49, 50]
# [49, 50, 51]
# [50, 51, 52]
# [51, 52, 53]
# [52, 53, 54]
# [53, 54, 55]
# [54, 55, 56]
# [55, 56, 57]
# [56, 57, 58]
# [57, 58, 59]
# [58, 59, 60]
# [59, 60, 61]
# [60, 61, 62]
# [61, 62, 63]
# [62, 63, 64]
# [63, 64, 65]
# [64, 65, 66]
# [65, 66, 67]
# [66, 67, 68]
# [67, 68, 69]
# [68, 69, 70]
# [69, 70, 71]
# [70, 71, 72]
# [71, 72, 73]
# [72, 73, 74]
# [73, 74, 75]
# [74, 75, 76]
# [75, 76, 77]
# [76, 77, 78]
# [77, 78, 79]
# [78, 79, 80]
# [79, 80, 81]
# [80, 81, 82]
# [81, 82, 83]
# [82, 83, 84]
# [83, 84, 85]
# [84, 85, 86]
# [85, 86, 87]
# [86, 87, 88]
# [87, 88, 89]
# [88, 89, 90]
# [89, 90, 91]
# [90, 91, 92]
# [91, 92, 93]
# [92, 93, 94]
# [93, 94, 95]
# [94, 95, 96]
# [95, 96, 97]
# [96, 97, 98]
# [97, 98, 99]
# [98, 99, 100]
# [99, 100, 101]
# [100, 101, 102]
# [101, 102, 103]
# [102, 103, 104]
# [103, 104, 105]
# [104, 105, 106]
# [105, 106, 107]
# [106, 107, 108]
# [107, 108, 109]
# [108, 109, 110]
# [109, 110, 111]
# [110, 111, 112]
# [111, 112, 113]
# [112, 113, 114]
# [113, 114, 115]
# [114, 115, 116]
# [115, 116, 117]
# [116, 117, 118]
# [117, 118, 119]
# [118, 119, 120]
# [119, 120, 121]
# [120, 121, 122]
# [121, 122, 123]
# [122, 123, 124]
# [123, 124, 125]
# [124, 125, 126]
# [125, 126, 127]
# [126, 127, 128]
# [127, 128, 129]
# [128, 129, 130]
# [129, 130, 131]
# [130, 131, 132]
# [131, 132, 133]
# [132, 133, 134]
# [133, 134, 135]
# [134, 135, 136]
# [135, 136, 137]
# [136, 137, 138]
# [137, 138, 139]
# [138, 139, 140]
# [139, 140, 141]
# [140, 141, 142]
# [141, 142, 143]
# [142, 143, 144]
# [143, 144, 145]
# [144, 145, 146]
# [145, 146, 147]
# [146, 147, 148]
# [147, 148, 149]
# [148, 149, 150]
# [149, 150, 151]
# [150, 151, 152]
# [151, 152, 153]
# [152, 153, 154]
# [153, 154, 155]
# [154, 155, 156]
# [155, 156, 157]
# [156, 157, 158]
# [157, 158, 159]
# [158, 159, 160]
# [159, 160, 161]
# [160, 161, 162]
# [161, 162, 163]
# [162, 163, 164]
# [163, 164, 165]
# [164, 165, 166]
# [165, 166, 167]
# [166, 167, 168]
# [167, 168, 169]
# [168, 169, 170]
# [169, 170, 171]
# [170, 171, 172]
# [171, 172, 173]
# [172, 173, 174]
# [173, 174, 175]
# [174, 175, 176]
# [175, 176, 177]
# [176, 177, 178]
# [177, 178, 179]
# [178, 179, 180]
# [179, 180, 181]
# [180, 181, 182]
# [181, 182, 183]
# [182, 183, 184]
# [183, 184, 185]
# [184, 185, 186]
# [185, 186, 187]
# [186, 187, 188]
# [187, 188, 189]
# [188, 189, 190]
# [189, 190, 191]
# [190, 191, 192]
# [191, 192, 193]
# [192, 193, 194]
# [193, 194, 195]
# [194, 195, 196]
# [195, 196, 197]
# [196, 197, 198]
# [197, 198, 199]
# [198, 199, 200]
# [199, 200, 201]
# [200, 201, 202]
# [201, 202, 203]
# [202, 203, 204]
# [203, 204, 205]
# [204, 205, 206]
# [205, 206, 207]
# [206, 207, 208]
# [207, 208, 209]
# [208, 209, 210]
# [209, 210, 211]
# [210, 211, 212]
# [211, 212, 213]
# [212, 213, 214]
# [213, 214, 215]
# [214, 215, 216]
# [215, 216, 217]
# [216, 217, 218]
# [217, 218, 219]
# [218, 219, 220]
# [219, 220, 221]
# [220, 221, 222]
# [221, 222, 223]
# [222, 223, 224]
# [223, 224, 225]
# [224, 225, 226]
# [225, 226, 227]
# [226, 227, 228]
# [227, 228, 229]
# [228, 229, 230]
# [229, 230, 231]
# [230, 231, 232]
# [231, 232, 233]
# [232, 233, 234]
# [233, 234, 235]
# [234, 235, 236]
# [235, 236, 237]
# [236, 237, 238]
# [237, 238, 239]
# [238, 239, 240]
# [239, 240, 241]
# [240, 241, 242]
# [241, 242, 243]
# [242, 243, 244]
# [243, 244, 245]
# [244, 245, 246]
# [245, 246, 247]
# [246, 247, 248]
# [247, 248, 249]
# [248, 249, 250]
# [249, 250, 251]
# [250, 251, 252]
# [251, 252, 253]
# [252, 253, 254]
# [253, 254, 255]
# [254, 255, 256]
# [255, 256, 257]
# [256, 257, 258]
# [257, 258, 259]
# [258, 259, 260]
# [259, 260, 261]
# [260, 261, 262]
# [261, 262, 263]
# [262, 263, 264]
# [263, 264, 265]
# [264, 265, 266]
# [265, 266, 267]
# [266, 267, 268]
# [267, 268, 269]
# [268, 269, 270]
# [269, 270, 271]
# [270, 271, 272]
# [271, 272, 273]
# [272, 273, 274]
# [273, 274, 275]
# [274, 275, 276]
# [275, 276, 277]
# [276, 277, 278]
# [277, 278, 279]
# [278, 279, 280]
# [279, 280, 281]
# [280, 281, 282]
# [281, 282, 283]
# [282, 283, 284]
# [283, 284, 285]
# [284, 285, 286]
# [285, 286, 287]
# [286, 287, 288]
# [287, 288, 289]
# [288, 289, 290]
# [289, 290, 291]
# [290, 291, 292]
# [291, 292, 293]
# [292, 293, 294]
# [293, 294, 295]
# [294, 295, 296]
# [295, 296, 297]
# [296, 297, 298]
# [297, 298, 299]
# [298, 299, 300]
# [299, 300, 301]
# [300, 301, 302]
# [301, 302, 303]
# [302, 303, 304]
# [303, 304, 305]
# [304, 305, 306]
# [305, 306, 307]
# [306, 307, 308]
# [307, 308, 309]
# [308, 309, 310]
# [309, 310, 311]
# [310, 311, 312]
# [311, 312, 313]
# [312, 313, 314]
# [313, 314, 315]
# [314, 315, 316]
# [315, 316, 317]
# [316, 317, 318]
# [317, 318, 319]
# [318, 319, 320]
# [319, 320, 321]
# [320, 321, 322]
# [321, 322, 323]
# [322, 323, 324]
# [323, 324, 325]
# [324, 325, 326]
# [325, 326, 327]
# [326, 327, 328]
# [327, 328, 329]
# [328, 329, 330]
# [329, 330, 331]
# [330, 331, 332]
# [331, 332, 333]
# [332, 333, 334]
# [333, 334, 335]
# [334, 335, 336]
# [335, 336, 337]
# [336, 337, 338]
# [337, 338, 339]
# [338, 339, 340]
# [339, 340, 341]
# [340, 341, 342]
# [341, 342, 343]
# [342, 343, 344]
# [343, 344, 345]
# [344, 345, 346]
# [345, 346, 347]
# [346, 347, 348]
# [347, 348, 349]
# [348, 349, 350]
# [349, 350, 351]
# [350, 351, 352]
# [351, 352, 353]
# [352, 353, 354]
# [353, 354, 355]
# [354, 355, 356]
# [355, 356, 357]
# [356, 357, 358]
# [357, 358, 359]
# [358, 359, 360]
# [359, 360, 361]
# [360, 361, 362]
# [361, 362, 363]
# [362, 363, 364]
# [363, 364, 365]
# [364, 365, 366]
# [365, 366, 367]
# [366, 367, 368]
# [367, 368, 369]
# [368, 369, 370]
# [369, 370, 371]
# [370, 371, 372]
# [371, 372, 373]
# [372, 373, 374]
# [373, 374, 375]
# [374, 375, 376]
# [375, 376, 377]
# [376, 377, 378]
# [377, 378, 379]
# [378, 379, 380]
# [379, 380, 381]
# [380, 381, 382]
# [381, 382, 383]
# [382, 383, 384]
# [383, 384, 385]
# [384, 385, 386]
# [385, 386, 387]
# [386, 387, 388]
# [387, 388, 389]
# [388, 389, 390]
# [389, 390, 391]
# [390, 391, 392]
# [391, 392, 393]
# [392, 393, 394]
# [393, 394, 395]
# [394, 395, 396]
# [395, 396, 397]
# [396, 397, 398]
# [397, 398, 399]
# [398, 399, 400]
# [399, 400, 401]
# [400, 401, 402]
# [401, 402, 403]
# [402, 403, 404]
# [403, 404, 405]
# [404, 405, 406]
# [405, 406, 407]
# [406, 407, 408]
# [407, 408, 409]
# [408, 409, 410]
# [409, 410, 411]
# [410, 411, 412]
# [411, 412, 413]
# [412, 413, 414]
# [413, 414, 415]
# [414, 415, 416]
# [415, 416, 417]
# [416, 417, 418]
# [417, 418, 419]
# [418, 419, 420]
# [419, 420, 421]
# [420, 421, 422]
# [421, 422, 423]
# [422, 423, 424]
# [423, 424, 425]
# [424, 425, 426]
# [425, 426, 427]
# [426, 427, 428]
# [427, 428, 429]
# [428, 429, 430]
# [429, 430, 431]
# [430, 431, 432]
# [431, 432, 433]
# [432, 433, 434]
# [433, 434, 435]
# [434, 435, 436]
# [435, 436, 437]
# [436, 437, 438]
# [437, 438, 439]
# [438, 439, 440]
# [439, 440, 441]
# [440, 441, 442]
# [441, 442, 443]
# [442, 443, 444]
# [443, 444, 445]
# [444, 445, 446]
# [445, 446, 447]
# [446, 447, 448]
# [447, 448, 449]
# [448, 449, 450]
# [449, 450, 451]
# [450, 451, 452]
# [451, 452, 453]
# [452, 453, 454]
# [453, 454, 455]
# [454, 455, 456]
# [455, 456, 457]
# [456, 457, 458]
# [457, 458, 459]
# [458, 459, 460]
# [459, 460, 461]
# [460, 461, 462]
# [461, 462, 463]
# [462, 463, 464]
# [463, 464, 465]
# [464, 465, 466]
# [465, 466, 467]
# [466, 467, 468]
# [467, 468, 469]
# [468, 469, 470]
# [469, 470, 471]
# [470, 471, 472]
# [471, 472, 473]
# [472, 473, 474]
# [473, 474, 475]
# [474, 475, 476]
# [475, 476, 477]
# [476, 477, 478]
# [477, 478, 479]
# [478, 479, 480]
# [479, 480, 481]
# [480, 481, 482]
# [481, 482, 483]
# [482, 483, 484]
# [483, 484, 485]
# [484, 485, 486]
# [485, 486, 487]
# [486, 487, 488]
# [487, 488, 489]
# [488, 489, 490]
# [489, 490, 491]
# [490, 491, 492]
# [491, 492, 493]
# [492, 493, 494]
# [493, 494, 495]
# [494, 495, 496]
# [495, 496, 497]
# [496, 497, 498]
# [497, 498, 499]
# done.
# Adding exp self avoidance between all particles ... done.
# [  0 499   0]

# %%
ActivePolymer.runSims(sim, nblocks=500, blocksize=300, )
# Out:
# Number of exceptions: 499
# adding force  ActiveForce 0
# adding force  RadialConfinement 1
# adding force  HarmonicBond 2
# adding force  BendingStiffness 3
# Add exclusions for SelfAvoidance force
# adding force  SelfAvoidance 4
# Add exclusions for LengthwiseCompaction_0 force
# adding force  LengthwiseCompaction_0 5
# Add exclusions for CustomTypes force
# adding force  CustomTypes 6
# Positions...
#  loaded!
# potential energy is 7747.659000
# bl=1 pos[1]=[8.9 -1.0 -1.2] dr=19.22 kin=2.09 pot=2.67 Rg=8.679 SPS=417
#
# Statistics for the simulation test, number of particles: 500,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.37505967  0.18510295  0.46730925]   Rg =  7.1992626
#      median bond size is  1.2652287856924913
#      three shortest/longest (<10)/ bonds are  [0.29112375 0.33913326 0.34035542]    [2.26109536 2.28461515 2.63121412]
#      95 percentile of distance to center is:    9.636475270238128
#      density of closest 95% monomers is:    0.12672151798387096
#      density of the core monomers is:    0.26010197221870146
#      min/median/mean/max coordinates are:
#      x: -9.07, -0.24, -0.38, 9.24
#      y: -9.70, 0.37, 0.19, 9.65
#      z: -8.59, 0.54, 0.47, 8.70
#
# Statistics for velocities:
#      mean kinetic energy is:  176.06061193950197 should be: 1.5
#      fastest particles are (in kT):  [2049.887177   2088.41746409 2225.60510614 2359.27843912 2521.01012558]
#
# Statistics for the system:
#      Forces are:  ['ActiveForce', 'RadialConfinement', 'HarmonicBond', 'BendingStiffness', 'SelfAvoidance', 'LengthwiseCompaction_0', 'CustomTypes']
#      Number of exceptions:   499
#
# Potential Energy Ep =  2.224591552734375
# bl=101 pos[1]=[1.9 4.9 4.0] dr=2.03 kin=183.44 pot=2.11 Rg=7.413 SPS=1055
#
# Statistics for the simulation test, number of particles: 500,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.35299524 -0.34505059  0.26626549]   Rg =  7.540135
#      median bond size is  1.2227252382028446
#      three shortest/longest (<10)/ bonds are  [0.38367037 0.41972162 0.4277568 ]    [2.01724544 2.02954322 2.13806226]
#      95 percentile of distance to center is:    9.649873703775596
#      density of closest 95% monomers is:    0.1261944084401017
#      density of the core monomers is:    0.10454234303854187
#      min/median/mean/max coordinates are:
#      x: -9.59, -0.44, -0.35, 8.56
#      y: -9.71, -0.07, -0.35, 8.76
#      z: -8.55, 0.77, 0.27, 9.85
#
# Statistics for velocities:
#      mean kinetic energy is:  267.33714561146303 should be: 1.5
#      fastest particles are (in kT):  [3672.54994719 3685.19544187 3845.94608664 4385.42008132 4606.32136602]
#
# Statistics for the system:
#      Forces are:  ['ActiveForce', 'RadialConfinement', 'HarmonicBond', 'BendingStiffness', 'SelfAvoidance', 'LengthwiseCompaction_0', 'CustomTypes']
#      Number of exceptions:   499
#
# Potential Energy Ep =  2.132464111328125
# bl=201 pos[1]=[-2.3 4.2 -3.2] dr=1.93 kin=269.13 pot=2.05 Rg=7.659 SPS=1107
#
# Statistics for the simulation test, number of particles: 500,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [ 0.19428775 -0.05425547  0.26152056]   Rg =  7.381588
#      median bond size is  1.2506745710719542
#      three shortest/longest (<10)/ bonds are  [0.2990177  0.38752055 0.46004164]    [2.24697119 2.27643785 2.31718955]
#      95 percentile of distance to center is:    9.770788066408668
#      density of closest 95% monomers is:    0.12156714583147527
#      density of the core monomers is:    0.2011699555302562
#      min/median/mean/max coordinates are:
#      x: -9.94, 0.04, 0.19, 9.23
#      y: -9.72, 0.39, -0.05, 9.36
#      z: -8.52, 0.32, 0.26, 9.62
#
# Statistics for velocities:
#      mean kinetic energy is:  335.181997354814 should be: 1.5
#      fastest particles are (in kT):  [4452.09532578 4807.20388928 4973.76519432 4996.53833271 5233.96436236]
#
# Statistics for the system:
#      Forces are:  ['ActiveForce', 'RadialConfinement', 'HarmonicBond', 'BendingStiffness', 'SelfAvoidance', 'LengthwiseCompaction_0', 'CustomTypes']
#      Number of exceptions:   499
#
# Potential Energy Ep =  1.7355234375
# bl=301 pos[1]=[-2.3 -6.4 7.0] dr=2.02 kin=336.67 pot=1.52 Rg=7.494 SPS=882
#
# Statistics for the simulation test, number of particles: 500,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.14120349  0.78002297 -0.57315151]   Rg =  7.5428176
#      median bond size is  1.2445672130463983
#      three shortest/longest (<10)/ bonds are  [0.32939997 0.35263941 0.39289351]    [2.17241353 2.22001468 2.38891237]
#      95 percentile of distance to center is:    9.929133445167796
#      density of closest 95% monomers is:    0.11584330987105425
#      density of the core monomers is:    0.16583668701002222
#      min/median/mean/max coordinates are:
#      x: -9.88, 0.33, -0.14, 9.78
#      y: -8.85, 0.62, 0.78, 9.40
#      z: -8.76, -0.87, -0.57, 9.46
#
# Statistics for velocities:
#      mean kinetic energy is:  372.9841689631814 should be: 1.5
#      fastest particles are (in kT):  [3595.35987264 3821.65799882 4121.7744037  4246.12317201 5596.25105214]
#
# Statistics for the system:
#      Forces are:  ['ActiveForce', 'RadialConfinement', 'HarmonicBond', 'BendingStiffness', 'SelfAvoidance', 'LengthwiseCompaction_0', 'CustomTypes']
#      Number of exceptions:   499
#
# Potential Energy Ep =  1.4677999267578126
# bl=401 pos[1]=[-4.3 0.4 1.5] dr=1.98 kin=364.33 pot=1.55 Rg=7.538 SPS=1078
#
# Statistics for the simulation test, number of particles: 500,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [0.98695161 0.65600231 0.56238603]   Rg =  7.507727
#      median bond size is  1.2838316106015375
#      three shortest/longest (<10)/ bonds are  [0.18278835 0.44487165 0.49927067]    [2.13898168 2.20661891 2.29308516]
#      95 percentile of distance to center is:    10.093752127166647
#      density of closest 95% monomers is:    0.1102673896591813
#      density of the core monomers is:    0.1879953988520002
#      min/median/mean/max coordinates are:
#      x: -9.41, 1.30, 0.99, 9.68
#      y: -8.88, 0.66, 0.66, 9.39
#      z: -9.79, 0.73, 0.56, 10.03
#
# Statistics for velocities:
#      mean kinetic energy is:  389.9542197786479 should be: 1.5
#      fastest particles are (in kT):  [4006.69207341 4444.33228818 5176.93421658 6637.13357777 6762.46147099]
#
# Statistics for the system:
#      Forces are:  ['ActiveForce', 'RadialConfinement', 'HarmonicBond', 'BendingStiffness', 'SelfAvoidance', 'LengthwiseCompaction_0', 'CustomTypes']
#      Number of exceptions:   499
#
# Potential Energy Ep =  1.1191549072265625

# %%
# Out:
# Number of exceptions: 90
# adding force  ActiveForce 0
# adding force  RadialConfinement 1
# adding force  HarmonicBond 2
# Positions...
#  loaded!
# potential energy is 0.004632
# bl=1 pos[1]=[7.9 -0.2 -0.5] dr=1.71 t=0.0ps kin=0.00 pot=0.69 Rg=5.526 SPS=1169
# saved
# bl=2 pos[1]=[7.0 0.6 0.2] dr=1.69 t=0.0ps kin=0.00 pot=0.48 Rg=5.338 SPS=1382
# saved
# bl=3 pos[1]=[8.1 0.7 0.3] dr=1.54 t=0.0ps kin=0.00 pot=0.57 Rg=5.272 SPS=1497
# saved
# bl=4 pos[1]=[6.6 0.0 -0.2] dr=1.67 t=0.0ps kin=0.00 pot=0.58 Rg=5.520 SPS=1720
# saved
# bl=5 pos[1]=[6.6 1.2 0.7] dr=1.58 t=0.0ps kin=0.00 pot=0.63 Rg=5.524 SPS=1871
# saved
# bl=6 pos[1]=[7.9 -0.3 1.1] dr=1.57 t=0.0ps kin=0.00 pot=0.43 Rg=5.489 SPS=2012
# saved
# bl=7 pos[1]=[8.9 1.5 -0.5] dr=1.65 t=0.0ps kin=0.00 pot=0.68 Rg=5.583 SPS=2124
# saved
# bl=8 pos[1]=[6.2 2.1 -0.9] dr=1.67 t=0.0ps kin=0.00 pot=0.54 Rg=5.562 SPS=2185
# saved
# bl=9 pos[1]=[6.3 1.3 0.6] dr=1.66 t=0.0ps kin=0.00 pot=0.48 Rg=5.449 SPS=2365
# saved
# bl=10 pos[1]=[5.2 1.9 0.1] dr=1.63 t=0.0ps kin=0.00 pot=0.55 Rg=5.301 SPS=2400
# saved

# %%
import numpy as np
xyz=np.load('test_out/traj_test_positions.npy')
xyz.shape
# Out:
# (10, 1200, 3)

# %%
sample_snap=xyz[-1,:,:]
sample_snap.shape
np.save('input_files/sample_snap_1200.npy', sample_snap)

# %%
import matplotlib.pyplot as plt
import numpy as np

d=np.load('/Users/sumitabha/Box/Active_fluctuations/Active-noise-simulations/sim_codes/analyze_traj_Rouse_chain_T300.0_F0.0_Ta1.0_Esoft0_R0500.0_Na1200_blocksize100_kb10.0_dt0.001_kr30.0_shape_descriptors.npz')

# %%
plt.plot(d['rg'][1], d['rg'][0],'.-')
# plt.xlim(0,4)

# %%
#==========================#
#Initialize Michrom Class  #
#==========================#
sim=MiChroM(name=savename, velocity_reinitialize=False,temperature=T)

#Specify integrator
integrator=CustomBrownianIntegrator(
                    timestep=dt * unit.picoseconds, 
                    collision_rate=gamma / unit.picoseconds,
                    temperature=T * unit.kelvin,measure_heat=False,
                    noise_corr=Ta * unit.picoseconds,
                    )

sim.setup(platform="opencl",integrator=integrator,)
sim.saveFolder(opath)

#Initial structure (spiral by default)
if '.npy' not in finit:
    chrm=sim.create_springSpiral(ChromSeq=fseq)
else:
    chrm=np.load(finit)
sim.loadStructure(chrm,center=True)
sim._translate_type(fseq)

sim.timestep=0.2
print(sim.timestep)
# Out:
#     ***************************************************************************************
#      **** **** *** *** *** *** *** *** OpenMiChroM-1.0.2 *** *** *** *** *** *** **** ****
#
#          OpenMiChroM is a Python library for performing chromatin dynamics simulations.
#                             OpenMiChroM uses the OpenMM Python API,
#                 employing the MiChroM (Minimal Chromatin Model) energy function.
#       The chromatin dynamics simulations generate an ensemble of 3D chromosomal structures
#       that are consistent with experimental Hi-C maps, also allows simulations of a single
#                  or multiple chromosome chain using High-Performance Computing
#                             in different platforms (GPUs and CPUs).
#          OpenMiChroM documentation is available at https://open-michrom.readthedocs.io
#
#          OpenMiChroM is described in: Oliveira Junior, A. B & Contessoto, V, G et. al.
#       A Scalable Computational Approach for Simulating Complexes of Multiple Chromosomes.
#                   Journal of Molecular Biology. doi:10.1016/j.jmb.2020.10.034.
#                                               and
#                                  Oliveira Junior, A. B. et al.
#      Chromosome Modeling on Downsampled Hi-C Maps Enhances the Compartmentalization Signal.
#                         J. Phys. Chem. B, doi:10.1021/acs.jpcb.1c04174.
#
#                     Copyright (c) 2021, The OpenMiChroM development team at
#                                         Rice University
#     ***************************************************************************************
# 0.2

# %%
Custom_Bonds.set_activity(sim,F_act=1, particle_list=range(50))


##---------#
##polymers #
##---------#

#chromosome topology
chrm_top=np.loadtxt(ftop, delimiter=' ', dtype=int)
# sim.forceDict['HarmonicBond']=sim.mm.HarmonicBondForce()
##add bonds between nearest neighbors
for ii in range(sim.N-1):
    #skip bonds between different chromosomes
    if ii in chrm_top[:,1]: continue
    Custom_Bonds.addFENEBond(sim, ii, ii+1,kfb=20)
    # Custom_Bonds.addTanhHarmonicBond(sim, ii, ii+1, eh=20, kb=kb)
    # print(ii)
    # sim.forceDict['HarmonicBond'].addBond(ii,ii+1, 2, 1)
    # sim.bondsForException.append((int(ii), int(ii+1)))
    # Custom_Bonds.addHarmonicBond(sim, ii, ii+1, kb=kb, d=2) 

Custom_Bonds.addRadialConfinement(sim, R0=R0, FlatBottomHarmonic=True, kr=50)

#=====================#
# Soft-core repulsion #
#=====================#
# Custom_Bonds.addTanhRepulsion(sim, es=4,rc=1)

#=========================#
# Inter-monomer adhesion  #
#=========================#
# sim.addCustomTypes(mu=3, rc=1, TypesTable='type_table.csv')
# Custom_Bonds.LJRepulsion(sim)
# Custom_Bonds.HarmonicRepulsion(sim,k0=30,r0=1.)
# Custom_Bonds.TypesAdhesionGaussian(sim,rc=1.,TypesTable='type_table.csv')
# Custom_Bonds.addCustomTypes(sim,rc=2,TypesTable='type_table.csv')
# Out:
# Implementing Flat-Bottom Harmonic confinement:
#  Radius: 50.00
#  Volume fraction: 0.000
#  Stiffness: 50.00
# True

# %%
for key in sim.forceDict:
    print(key, sim.forceDict[key].getForceGroup())#,sim.forceDict[key].getNumParticles(),)
#     sim.forceDict[key].getNumPerParticleParameters(),sim.forceDict[key].getParticleParameters(70))
# print(sim.forceDict['CustomTypes'].getParticleParameters(200))
# print(sim.forceDict['ActiveForce'].getNumParticles())
# sim.forceDict['HarmonicBond'].getGlobalParameterDefaultValue(1,)
# sim.forceDict['HarmonicBond'].getNumBonds()
# sim.forceDict['HarmonicBond'].getNumGlobalParameters()
# print(chrm_top.shape)
# Out:
# ActiveForce 0
# FENEBond 0
# RadialConfinement 0

# %%
positions=[]
for ii, _ in enumerate(range(nblocks)):
    sim.runSimBlock(blocksize)
    #sim.saveStructure()

    state = sim.context.getState(getPositions=True,
            getVelocities=False, getEnergy=False)
    #vel = state.getVelocities(asNumpy=True)#/unit.sqrt(unit.kilojoule_per_mole / mass)
    positions.append(state.getPositions(asNumpy=True))
#     sim.printForces()
#     print(sim.state.getPotentialEnergy(), sim.kB*T*unit.kelvin)
    
    # if ii%int(args.nblocks*0.1)==0 and ii>0==0:
    if ii==500:
        np.save(opath+'traj_'+savename+'_positions.npy',np.array(positions))
        print('saved')
#save cndb file
#sim.storage[0].close()

#np.save(args.opath+savename+'_velocities.npy',Velocities)
np.save(opath+'traj_'+savename+'_positions.npy',np.array(positions))
# Out:
# Number of exceptions: 0
# adding force  ActiveForce 0
# adding force  FENEBond 1
# adding force  RadialConfinement 2
# Positions...
#  loaded!
# potential energy is 7.781780
# bl=1 pos[1]=[4.5 2.3 1.2] dr=2.74 t=0.0ps kin=3.18 pot=-0.89 Rg=5.577 SPS=1477
# bl=2 pos[1]=[5.3 1.7 -1.3] dr=2.12 t=0.0ps kin=7.00 pot=-0.98 Rg=6.180 SPS=2456
# bl=3 pos[1]=[5.9 3.0 -2.5] dr=1.44 t=0.0ps kin=9.16 pot=-1.11 Rg=6.462 SPS=2483
# bl=4 pos[1]=[5.0 5.4 -2.1] dr=1.71 t=0.0ps kin=11.60 pot=-2.12 Rg=6.703 SPS=2477
# bl=5 pos[1]=[6.8 5.7 -0.0] dr=1.95 t=0.0ps kin=14.61 pot=-2.49 Rg=6.769 SPS=2512
# bl=6 pos[1]=[6.4 4.9 -1.1] dr=1.70 t=0.0ps kin=18.74 pot=-2.13 Rg=6.533 SPS=2549
# bl=7 pos[1]=[6.9 4.5 -1.1] dr=1.56 t=0.0ps kin=21.23 pot=-2.60 Rg=7.006 SPS=2538
# bl=8 pos[1]=[4.8 4.7 -2.6] dr=1.28 t=0.0ps kin=24.24 pot=-1.94 Rg=6.638 SPS=2523
# bl=9 pos[1]=[6.7 4.3 -3.6] dr=1.54 t=0.0ps kin=24.93 pot=-1.85 Rg=6.565 SPS=2545
# bl=10 pos[1]=[5.2 4.4 -4.2] dr=1.99 t=0.0ps kin=28.15 pot=-2.45 Rg=6.416 SPS=2533
# bl=11 pos[1]=[5.6 4.1 -5.6] dr=2.04 t=0.0ps kin=30.27 pot=-2.24 Rg=6.571 SPS=2474
# bl=12 pos[1]=[4.5 2.9 -4.3] dr=1.84 t=0.0ps kin=31.98 pot=-1.91 Rg=6.002 SPS=2547
# bl=13 pos[1]=[3.7 5.0 -4.3] dr=1.66 t=0.0ps kin=33.41 pot=-2.28 Rg=6.057 SPS=2553
# bl=14 pos[1]=[2.0 4.5 -4.4] dr=1.99 t=0.0ps kin=36.39 pot=-2.45 Rg=5.838 SPS=2557
# bl=15 pos[1]=[1.8 4.5 -6.1] dr=1.56 t=0.0ps kin=34.20 pot=-1.38 Rg=6.499 SPS=2445
# bl=16 pos[1]=[2.4 3.4 -5.6] dr=1.65 t=0.0ps kin=37.98 pot=-1.36 Rg=6.487 SPS=2557
# bl=17 pos[1]=[0.2 4.0 -5.9] dr=1.46 t=0.0ps kin=40.08 pot=-1.36 Rg=6.697 SPS=2558
# bl=18 pos[1]=[1.1 5.3 -6.5] dr=1.75 t=0.0ps kin=45.01 pot=-1.19 Rg=7.086 SPS=2576
# bl=19 pos[1]=[-0.7 6.2 -6.2] dr=1.69 t=0.0ps kin=47.71 pot=-1.64 Rg=7.585 SPS=2528
# bl=20 pos[1]=[-1.0 7.1 -4.2] dr=1.53 t=0.0ps kin=46.29 pot=-2.05 Rg=7.111 SPS=2545
# bl=21 pos[1]=[-0.7 6.9 -5.0] dr=2.06 t=0.0ps kin=50.18 pot=-1.98 Rg=8.000 SPS=2580
# bl=22 pos[1]=[-2.5 6.8 -5.5] dr=1.39 t=0.0ps kin=57.48 pot=-1.82 Rg=8.036 SPS=2557
# bl=23 pos[1]=[-0.8 7.0 -6.4] dr=1.87 t=0.0ps kin=59.68 pot=-2.29 Rg=8.344 SPS=2593
# bl=24 pos[1]=[-1.7 6.4 -5.4] dr=1.48 t=0.0ps kin=61.87 pot=-1.79 Rg=8.418 SPS=2645
# bl=25 pos[1]=[-2.4 5.6 -6.4] dr=1.69 t=0.0ps kin=67.00 pot=-1.69 Rg=8.898 SPS=2657
# bl=26 pos[1]=[-2.6 4.4 -7.2] dr=1.68 t=0.0ps kin=73.86 pot=-1.65 Rg=8.411 SPS=2665
# bl=27 pos[1]=[-5.0 7.2 -8.5] dr=2.27 t=0.0ps kin=78.04 pot=-1.45 Rg=9.592 SPS=2671
# bl=28 pos[1]=[-5.7 6.4 -8.2] dr=1.38 t=0.0ps kin=82.66 pot=-1.54 Rg=9.330 SPS=2667
# bl=29 pos[1]=[-6.0 6.6 -9.2] dr=1.70 t=0.0ps kin=81.34 pot=-1.90 Rg=10.062 SPS=2659
# bl=30 pos[1]=[-5.9 7.6 -7.2] dr=1.87 t=0.0ps kin=79.49 pot=-2.72 Rg=10.193 SPS=2665
# bl=31 pos[1]=[-7.5 5.6 -6.5] dr=1.97 t=0.0ps kin=79.38 pot=-2.45 Rg=10.846 SPS=2662
# bl=32 pos[1]=[-8.2 5.3 -6.1] dr=1.84 t=0.0ps kin=84.60 pot=-3.67 Rg=11.090 SPS=2674
# bl=33 pos[1]=[-7.4 6.7 -6.4] dr=1.55 t=0.0ps kin=89.76 pot=-4.02 Rg=11.137 SPS=2681
# bl=34 pos[1]=[-9.9 6.8 -6.6] dr=1.84 t=0.0ps kin=94.53 pot=-3.20 Rg=11.705 SPS=2662
# bl=35 pos[1]=[-9.5 6.5 -6.4] dr=1.91 t=0.0ps kin=94.74 pot=-3.73 Rg=11.999 SPS=2674
# bl=36 pos[1]=[-9.4 6.3 -6.7] dr=1.96 t=0.0ps kin=96.32 pot=-3.81 Rg=13.264 SPS=2663
# bl=37 pos[1]=[-9.1 6.1 -6.2] dr=1.84 t=0.0ps kin=100.42 pot=-3.92 Rg=13.116 SPS=2576
# bl=38 pos[1]=[-9.1 5.5 -6.0] dr=1.82 t=0.0ps kin=101.57 pot=-4.49 Rg=14.142 SPS=2641
# bl=39 pos[1]=[-10.9 6.0 -4.1] dr=2.12 t=0.0ps kin=104.93 pot=-4.74 Rg=15.001 SPS=1764
# bl=40 pos[1]=[-12.3 6.1 -3.9] dr=1.56 t=0.0ps kin=108.55 pot=-5.24 Rg=15.297 SPS=2182
# bl=41 pos[1]=[-11.7 6.1 -4.5] dr=1.83 t=0.0ps kin=111.48 pot=-5.88 Rg=15.936 SPS=2593
# bl=42 pos[1]=[-14.7 6.9 -3.9] dr=2.13 t=0.0ps kin=109.28 pot=-5.99 Rg=17.061 SPS=2612
# bl=43 pos[1]=[-13.7 6.3 -3.7] dr=1.58 t=0.0ps kin=108.90 pot=-6.71 Rg=17.579 SPS=1947
# bl=44 pos[1]=[-14.2 7.8 -4.9] dr=1.88 t=0.0ps kin=107.45 pot=-7.81 Rg=18.531 SPS=2528
# bl=45 pos[1]=[-15.5 6.7 -4.2] dr=1.59 t=0.0ps kin=103.35 pot=-7.92 Rg=18.844 SPS=2620
# bl=46 pos[1]=[-14.4 7.6 -2.4] dr=1.56 t=0.0ps kin=106.42 pot=-8.46 Rg=18.489 SPS=2283
# bl=47 pos[1]=[-12.7 7.5 -4.0] dr=1.45 t=0.0ps kin=108.36 pot=-8.75 Rg=18.914 SPS=1773
# bl=48 pos[1]=[-13.9 9.4 -4.0] dr=1.90 t=0.0ps kin=112.06 pot=-9.00 Rg=19.874 SPS=2638
# bl=49 pos[1]=[-16.6 9.3 -3.1] dr=1.82 t=0.0ps kin=112.54 pot=-9.65 Rg=20.797 SPS=2627
#
# Statistics for the simulation test, number of particles: 100,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [ 8.14385851 -0.4954015   8.09129012]   Rg =  20.797203
#      median bond size is  0.3544905676739484
#      three shortest/longest (<10)/ bonds are  [0.05517124 0.07837065 0.07978325]    [0.66481159 0.664825   0.67509624]
# longest 10 bonds are [ 0.61900234  0.62737724  0.64553353  0.66481159  0.664825    0.67509624
#  14.12164931 21.04498577 24.1109338  59.58179967]
#      95 percentile of distance to center is:    32.65467469831219
#      density of closest 95% monomers is:    0.0006513267436528667
#      density of the core monomers is:    0.006260103048340047
#      min/median/mean/max coordinates are:
#      x: -16.58, 9.46, 8.14, 34.64
#      y: -7.81, -3.35, -0.50, 10.05
#      z: -3.34, 4.62, 8.09, 27.06
#
# Statistics for velocities:
#      mean kinetic energy is:  112.5371668816403 should be: 1.5
#      fastest particles are (in kT):  [410.79862776 453.44858822 546.36548193 589.874691   641.7292142 ]
#
# Statistics for the system:
#      Forces are:  ['ActiveForce', 'FENEBond', 'RadialConfinement']
#      Number of exceptions:   0
#
# Potential Energy Ep =  -9.653195190429688
# bl=50 pos[1]=[-17.2 9.4 -3.1] dr=2.06 t=0.0ps kin=109.94 pot=-10.43 Rg=21.743 SPS=2641
# bl=51 pos[1]=[-17.3 10.5 -2.4] dr=1.65 t=0.0ps kin=114.36 pot=-10.52 Rg=22.120 SPS=2651
# bl=52 pos[1]=[-16.8 11.1 -2.5] dr=1.79 t=0.0ps kin=117.81 pot=-11.55 Rg=22.510 SPS=2627
# bl=53 pos[1]=[-16.5 13.3 -2.9] dr=2.26 t=0.0ps kin=121.66 pot=-12.30 Rg=23.121 SPS=2633
# bl=54 pos[1]=[-16.8 15.9 -4.6] dr=2.20 t=0.0ps kin=123.10 pot=-13.06 Rg=24.108 SPS=2624
# bl=55 pos[1]=[-15.0 15.4 -4.3] dr=1.96 t=0.0ps kin=127.92 pot=-14.29 Rg=24.842 SPS=2639
# bl=56 pos[1]=[-16.1 16.7 -5.5] dr=1.59 t=0.0ps kin=125.84 pot=-13.79 Rg=25.091 SPS=2558
# bl=57 pos[1]=[-17.0 17.8 -3.9] dr=1.95 t=0.0ps kin=128.79 pot=-14.36 Rg=25.635 SPS=2187
# bl=58 pos[1]=[-18.1 19.4 -5.5] dr=1.92 t=0.0ps kin=134.42 pot=-14.85 Rg=26.304 SPS=1635
# bl=59 pos[1]=[-19.6 21.3 -6.1] dr=2.16 t=0.0ps kin=134.41 pot=-14.99 Rg=27.474 SPS=2077
# bl=60 pos[1]=[-21.3 22.1 -7.3] dr=1.72 t=0.0ps kin=131.82 pot=-15.24 Rg=28.477 SPS=2663
# bl=61 pos[1]=[-20.5 23.0 -9.0] dr=1.92 t=0.0ps kin=135.29 pot=-15.07 Rg=29.059 SPS=2384
# bl=62 pos[1]=[-19.7 25.9 -9.5] dr=1.57 t=0.0ps kin=139.73 pot=-15.77 Rg=29.311 SPS=2403
# bl=63 pos[1]=[-21.8 26.5 -9.4] dr=1.67 t=0.0ps kin=140.11 pot=-16.01 Rg=29.564 SPS=2645
# bl=64 pos[1]=[-22.4 25.9 -8.6] dr=1.29 t=0.0ps kin=141.12 pot=-15.62 Rg=30.076 SPS=2647
# bl=65 pos[1]=[-24.9 25.4 -11.9] dr=2.14 t=0.0ps kin=144.87 pot=-15.20 Rg=31.054 SPS=2644
# bl=66 pos[1]=[-24.4 25.4 -12.6] dr=1.05 t=0.0ps kin=147.72 pot=-15.81 Rg=31.369 SPS=2629
# bl=67 pos[1]=[-25.4 26.7 -11.2] dr=1.56 t=0.0ps kin=151.84 pot=-15.97 Rg=31.861 SPS=2163
# bl=68 pos[1]=[-23.8 27.6 -13.6] dr=1.50 t=0.0ps kin=150.69 pot=-15.92 Rg=32.224 SPS=2279
# bl=69 pos[1]=[-25.3 30.0 -14.6] dr=1.73 t=0.0ps kin=152.25 pot=-16.55 Rg=32.802 SPS=2591
# bl=70 pos[1]=[-25.1 31.4 -15.9] dr=1.89 t=0.0ps kin=149.81 pot=-16.59 Rg=33.290 SPS=2605
# bl=71 pos[1]=[-26.3 32.6 -17.2] dr=2.13 t=0.0ps kin=157.68 pot=-16.29 Rg=33.960 SPS=1729
# bl=72 pos[1]=[-25.7 34.1 -17.7] dr=1.38 t=0.0ps kin=162.23 pot=-16.50 Rg=34.173 SPS=2647
# bl=73 pos[1]=[-25.2 34.8 -19.0] dr=1.85 t=0.0ps kin=161.39 pot=-17.39 Rg=34.624 SPS=2658
# bl=74 pos[1]=[-26.1 34.4 -18.3] dr=1.63 t=0.0ps kin=164.90 pot=-16.88 Rg=34.541 SPS=2657
# bl=75 pos[1]=[-24.4 34.2 -20.0] dr=1.86 t=0.0ps kin=170.92 pot=-17.00 Rg=34.831 SPS=2621
# bl=76 pos[1]=[-25.5 34.9 -20.2] dr=1.83 t=0.0ps kin=172.55 pot=-17.25 Rg=35.164 SPS=2623
# bl=77 pos[1]=[-26.5 35.4 -19.3] dr=1.33 t=0.0ps kin=175.86 pot=-17.51 Rg=35.545 SPS=2528
# bl=78 pos[1]=[-25.7 33.4 -20.2] dr=1.61 t=0.0ps kin=176.41 pot=-17.77 Rg=35.591 SPS=2610
# bl=79 pos[1]=[-25.9 34.3 -20.5] dr=1.52 t=0.0ps kin=181.90 pot=-17.50 Rg=35.806 SPS=2609
# bl=80 pos[1]=[-26.4 35.6 -20.9] dr=1.69 t=0.0ps kin=183.25 pot=-18.56 Rg=35.846 SPS=2620
# bl=81 pos[1]=[-27.1 35.2 -19.6] dr=1.71 t=0.0ps kin=185.58 pot=-18.75 Rg=35.659 SPS=2658
# bl=82 pos[1]=[-27.0 36.6 -18.7] dr=1.51 t=0.0ps kin=188.31 pot=-19.45 Rg=35.878 SPS=2414
# bl=83 pos[1]=[-25.5 37.9 -20.2] dr=1.98 t=0.0ps kin=194.01 pot=-19.64 Rg=35.406 SPS=2254
# bl=84 pos[1]=[-23.5 38.3 -21.4] dr=1.53 t=0.0ps kin=196.98 pot=-19.51 Rg=35.492 SPS=2443
# bl=85 pos[1]=[-23.1 37.6 -21.1] dr=1.52 t=0.0ps kin=199.34 pot=-19.72 Rg=35.361 SPS=2630
# bl=86 pos[1]=[-23.9 37.4 -22.3] dr=1.66 t=0.0ps kin=199.89 pot=-19.34 Rg=35.557 SPS=2284
# bl=87 pos[1]=[-22.0 38.0 -22.0] dr=1.62 t=0.0ps kin=202.85 pot=-19.81 Rg=35.194 SPS=2454
# bl=88 pos[1]=[-22.2 38.4 -21.6] dr=1.49 t=0.0ps kin=206.30 pot=-20.13 Rg=34.955 SPS=2663
# bl=89 pos[1]=[-21.5 38.1 -23.6] dr=1.11 t=0.0ps kin=207.66 pot=-19.94 Rg=35.055 SPS=2646
# bl=90 pos[1]=[-20.6 37.5 -23.1] dr=1.46 t=0.0ps kin=207.08 pot=-20.26 Rg=34.970 SPS=2635
# bl=91 pos[1]=[-19.1 39.8 -23.0] dr=1.64 t=0.0ps kin=211.70 pot=-21.00 Rg=35.152 SPS=2643
# bl=92 pos[1]=[-19.2 38.9 -24.2] dr=1.03 t=0.0ps kin=218.00 pot=-20.67 Rg=35.271 SPS=2656
# bl=93 pos[1]=[-19.6 39.9 -23.0] dr=1.58 t=0.0ps kin=225.49 pot=-20.73 Rg=35.493 SPS=2680
# bl=94 pos[1]=[-19.7 40.1 -22.2] dr=1.52 t=0.0ps kin=225.69 pot=-20.27 Rg=35.414 SPS=2647
# bl=95 pos[1]=[-20.8 38.8 -22.7] dr=1.53 t=0.0ps kin=224.41 pot=-20.32 Rg=35.512 SPS=2640
# bl=96 pos[1]=[-20.7 39.4 -22.5] dr=2.07 t=0.0ps kin=227.02 pot=-20.64 Rg=35.842 SPS=2640
# bl=97 pos[1]=[-20.8 38.6 -22.4] dr=1.59 t=0.0ps kin=229.31 pot=-20.39 Rg=35.468 SPS=2650
# bl=98 pos[1]=[-21.0 39.0 -23.0] dr=1.85 t=0.0ps kin=228.85 pot=-20.19 Rg=35.588 SPS=2651
# bl=99 pos[1]=[-20.0 38.9 -23.1] dr=1.68 t=0.0ps kin=234.45 pot=-20.17 Rg=35.655 SPS=2660
#
# Statistics for the simulation test, number of particles: 100,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [ 9.25697976 10.93773861  8.29905932]   Rg =  35.655445
#      median bond size is  0.38907923592245003
#      three shortest/longest (<10)/ bonds are  [0.10403357 0.10632717 0.13647095]    [0.7895641  0.86547407 0.90160692]
# longest 10 bonds are [ 0.68264111  0.73294832  0.74756821  0.7895641   0.86547407  0.90160692
#  29.46969021 38.47692416 57.86214069 75.62537498]
#      95 percentile of distance to center is:    50.98206467481787
#      density of closest 95% monomers is:    0.00017115229903868554
#      density of the core monomers is:    0.12728746440641928
#      min/median/mean/max coordinates are:
#      x: -20.51, 9.20, 9.26, 43.37
#      y: -10.19, 8.69, 10.94, 40.31
#      z: -23.40, 7.99, 8.30, 39.77
#
# Statistics for velocities:
#      mean kinetic energy is:  234.45303151529754 should be: 1.5
#      fastest particles are (in kT):  [1166.81298618 1282.56264311 1386.42228588 1721.55794444 2118.5451732 ]
#
# Statistics for the system:
#      Forces are:  ['ActiveForce', 'FENEBond', 'RadialConfinement']
#      Number of exceptions:   0
#
# Potential Energy Ep =  -20.170794677734374
# bl=100 pos[1]=[-21.2 38.9 -21.7] dr=1.82 t=0.0ps kin=234.26 pot=-20.00 Rg=35.637 SPS=2663

# %%
xyz=np.load(opath+'traj_'+savename+'_positions.npy')
print(xyz.shape)
# Out:
# (100, 100, 3)

# %%
np.savetxt('snap.csv',xyz[-1])

# %%
# %matplotlib ipympl
fig = plt.figure()
ax = fig.add_axes([0,0,2,2],projection='3d')
# ax = fig.add_axes([0,0,1,1],)
# quiver = ax.quiver([],[],[],[])
#quiver = ax.quiver([],[],[],[],[],[])
R0=100
Na=400
ax.scatter(xyz[0,:Na,0],xyz[0,:Na,1],xyz[0,:Na,2],'o',color='C0')
ax.scatter(xyz[0,Na:,0],xyz[0,Na:,1],xyz[0,Na:,2],'o',color='C1')
# c=['r','g','b']
def update(ii):
    fig.clear()
    ax = fig.add_axes([0,0,1,1],projection='3d')
    # ax = fig.add_axes([0,0,1,1],)

    p=xyz[ii]
    # print(p.shape)
    # line.set_data(p[:,0],p[:,1])
    # line.set_3d_properties(p[:,2])
    # plt.draw()
    # ax.plot(p[10:13,0],p[10:13,1],p[10:13,2],'o',color='C0',alpha=1)
    ax.scatter(p[:Na,0],p[:Na,1],p[:Na,2],'o',color='C0',alpha=0.5)

    # ax.plot(p[300:303,0],p[300:303,1],p[300:303,2],'o',color='C1',alpha=1)
    ax.scatter(p[Na:,0],p[Na:,1],p[Na:,2],'o',color='C1',)
    ax.plot(p[Na:,0],p[Na:,1],p[Na:,2],'-',color='k',)
    # ax.plot(masked_xyz[:100,0],masked_xyz[:100,1],'go',markersize=3)
    
    ax.set_zlim(-R0, R0)
    ax.set_xlim(-R0, R0)
    ax.set_ylim(-R0, R0)
    
    # return line,

#update(10)
ani = FuncAnimation(fig, update, frames=np.arange(1,xyz.shape[0],5), interval=200, blit=True,repeat=False)

# ani.save('ani_sticky_gas_T0.1_F0.1_Ta10-R20.gif', writer='pillow')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def autocorrFFT(x):
    Nx=len(x)
    F = np.fft.fft(x, n=2*Nx)  #2*N because of zero-padding
    PSD = F * F.conjugate()
    res = np.fft.ifft(PSD)
    res= (res[:Nx]).real   #now we have the autocorrelation in convention B
    n=Nx*np.ones(Nx)-np.arange(0,Nx) #divide res(m) by (N-m)
    return res/n #this is the autocorrelation in convention A
    
def msd_fft(r):
    Nx=len(r)
    D=np.square(r).sum(axis=1) 
    D=np.append(D,0) 
    S2=sum([autocorrFFT(r[:, i]) for i in range(r.shape[1])])
    Q=2*D.sum()
    S1=np.zeros(Nx)
    for m in range(Nx):
        Q=Q-D[m-1]-D[Nx-m]
        S1[m]=Q/(Nx-m)
    return S1,S2

def tau_p(p1,k1,Nn):
    g=0.1
    return g*Nn**2/(np.pi**2*k1*p1**2)
    
def tau_charac(k1):
    g=0.1
    return g/(np.pi**2*k1)

def XP_autocorr(t,p1,T1,F1,ta,k1,Nn):
    g=0.1
    tp=tau_p(p1,k1,Nn)
    r=1-ta**2/tp**2
    ret = ((3*tp/(2*Nn*g))*(T1+F1**2*ta/(g*r))*np.exp(-t/tp) 
            - (3*F1**2*ta**2/(2*Nn*g**2*r))*np.exp(-t/ta))
    # ret=((3*temp*tp/(2*Nn*g))*np.exp(-t/tp)
    #         + (3*(F1*tp*ta)**2/(2*Nn*g**2*(tp**2-ta**2)))*(tp*np.exp(-t/tp)/ta + np.exp(-t/ta)))
    return ret

def Rot_corr(t,T1,F1,ta,k1,Nn):
    #scalar t
    ps=np.arange(1,Nn,1)
    ret=XP_autocorr(t,ps,T1,F1,ta,k1,Nn)*(1+np.cos(ps*np.pi/Nn)**2-2*np.cos(ps*np.pi)*np.cos(np.pi*ps/Nn))
    return np.mean(ret)

def dXp_autocorr(t,p1,T1,F1,ta,k1,Nn):
    #scalar t
    c=0
    tp=tau_p(p1,k1,Nn)
    g=0.1
    if t<1e-8: c=T1/(Nn*g)

    # ret=c-T1*np.exp(-t/tp)/(2*Nn*g*tp)
    ret=(c+XP_autocorr(t,p1,T1,F1,ta,k1,Nn)/tp**2-T1*np.exp(-t/tp)/(Nn*g*tp)
            +(F1**2*(ta**2+tp**2)*np.exp(-t/ta) -2*F1**2*ta*tp*np.exp(-t/tp))/(2*Nn*g**2*(tp**2-ta**2)))
    return ret

# %%
ts=np.arange(0,xyz.shape[0],1)*blocksize*dt
k=16#chrm_top.shape[0]
N=50#int(sim.N/k)
p=10
for d in [1]:
    SXp=[]
    print(tau_p(p,kb,50))
    for pol in range(k):
        # print(pol*N,(pol+1)*N)
        Xp=(1/N)*np.einsum('ijk,j->ik',xyz[:,pol*N:(pol+1)*N,:],np.cos((p*np.pi/N)*(np.arange(1,N+1,1)+0.5)))
        # print(Xp.shape)
        dXp=(Xp[d:,:]-Xp[:-d,:])/(blocksize*dt)
        
        SXp.append(msd_fft(dXp)[1])
    
    SXp=np.mean(np.array(SXp),axis=0)

    plt.semilogx(ts[:-d], SXp/SXp[0],'.')
    # if p==0: continue
    # plt.semilogx(ts,XP_autocorr(t=ts,p1=p,T1=T,F1=F,ta=Ta,k1=kb,Nn=50),'k--')
    plt.plot(ts,[dXp_autocorr(xx,p1=p,T1=T,F1=F,ta=Ta,k1=kb,Nn=50)/dXp_autocorr(0,p1=p,T1=T,F1=F,ta=Ta,k1=kb,Nn=50) for xx in ts],'k--')

# plt.loglog()
plt.xscale('linear')
# print(SXp.shape)
plt.xlim(0,0.001)
# plt.ylim(-100,200)
# Out:
# 0.025330295910584444
# (0.0, 0.001)

# %%
np.gradient(ts)
# Out:
# array([0.001, 0.001, 0.001, ..., 0.001, 0.001, 0.001])

# %%
# %matplotlib inline
P1=np.array([xyz[:,(xx+1)*50-1,:]-xyz[:,xx*50,:] for xx in range(16)])
# print(P1.shape)
ts=np.arange(0,P1.shape[1],1)
Pav=np.mean([msd_fft(P1[xx])[1] for xx in range(16)],axis=0)
# print(Pav.shape)
plt.loglog(ts,Pav)
plt.loglog(np.logspace(0,3,20),[Rot_corr(xx,1,0,10,10,100) for xx in np.logspace(0,3,20)])

plt.ylim(1e-5,1e2)
# Rot_corr(10,1,1,10,10,100)
# Out:
# (1e-05, 100.0)

# %%
s=pd.read_table('chr_seq.txt', header=None)
# s.shape
print(s.shape)
# Out:
# (100, 1)

# %%
init=np.loadtxt('snap.csv',)
print(init.shape)
# Out:
# (100, 3)

# %%
chrm_top=np.loadtxt(ftop, delimiter=' ', dtype=int)

# %%
chrm_top.shape
# Out:
# (5, 3)

# %%
for row in chrm_top:
    print(row[0])
# Out:
# [ 0 19  0]
# [20 39  0]
# [40 59  0]
# [60 79  0]
# [80 99  0]

# %%
steps=10
num = steps // 5 + 1
for _ in range(steps // num):
    print(_)
# Out:
# 0
# 1
# 2

# %%
import AnalyzeTrajectory
import numpy as np
import matplotlib.pyplot as plt

# %%
d=np.load('test_out/traj_test_positions.npy')

# %%
np.pi
# Out:
# 3.141592653589793

# %%
traj=AnalyzeTrajectory.AnalyzeTrajectory(datafile='../../data/trajectory/sample_traj_Rouse_chain_T200.0_F1.0_Ta1000.0_Esoft0_R0500.0_Na1200_blocksize100_kb10.0_dt0.001_kr30.0_positions.npy', top_file='input_files/chromosome_top.txt')
# Out:
# =====================
# Loading topology file: input_files/chromosome_top.txt
#  done!
#
# Loading .npy trajectory: ../../data/trajectory/sample_traj_Rouse_chain_T200.0_F1.0_Ta1000.0_Esoft0_R0500.0_Na1200_blocksize100_kb10.0_dt0.001_kr30.0_positions.npy ... done!

# %%
msd=traj.compute_MSD_chains()
# Out:
# Computing Mean squared displacements... done!

# %%
msd[0].shape
# Out:
# (2000,)

# %%
plt.loglog(msd[0],'.-')

plt.loglog([1,10],np.array([1,10])**0.5,'k--')
plt.loglog([1e2,1e3],0.02*np.array([1e2,1e3])**2,'k--')
plt.ylim(1e-1,1e5)
plt.xlim(1,3e3)
# Out:
# (1, 3000.0)

# %%
d=traj.xyz
d.shape
# Out:
# (2000, 1200, 3)

# %%
drel=d[:,10,:] - d[:,80,:]
print(drel[0],d[0][10],d[0][80])
# Out:
# [-11.03894043 -31.93733215  57.91503906] [-494.58865356   12.25746536  -60.82170105] [-483.54971313   44.19479752 -118.73674011]

# %%
# msd_rel_70=[]
# msd_rel_diff_chains=[]
d70=d[:,10,:] - d[:,80,:]
d_diff_chains=d[:,10,:]-d[:,110,:]

s1,s2=AnalyzeTrajectory._msd_fft(d70)
msd_rel_70=s1-2*s2

s1,s2=AnalyzeTrajectory._msd_fft(d_diff_chains)
msd_rel_diff_chains=s1-2*s2

# %%
s1,s2=AnalyzeTrajectory._msd_fft(d[:,10,:]-d[:,800,:])
plt.loglog(s1-2*s2,'b.-')

s1,s2=AnalyzeTrajectory._msd_fft(d[:,10,:]-d[:,80,:])
plt.loglog(s1-2*s2,'r.-')

s1,s2=AnalyzeTrajectory._msd_fft(d[:,10,:]-d[:,20,:])
plt.loglog(s1-2*s2, 'g.-')

s1,s2=AnalyzeTrajectory._msd_fft(d[:,5,:]-d[:,95,:])
plt.loglog(s1-2*s2, 'm.-')

s1,s2=AnalyzeTrajectory._msd_fft(d[:,10,:]-d[:,30,:])
plt.loglog(s1-2*s2, 'y.-')

plt.loglog([1,10],10*np.array([1,10])**0.5,'k--')
plt.loglog([1e2,1e3],0.02*np.array([1e2,1e3])**2,'k--')


plt.ylim(2,1e3)
plt.xlim(1,3e3)
# Out:
# (1, 3000.0)

# %%
import matplotlib.pyplot as plt
import numpy as np

r=np.linspace(0,5,100)
eh_s=0.5 * 4 * (1 + np.tanh(6 * (0.5 - r)))
# eh_s=0.5*10*(r-1.5)**2*np.heaviside(1.5-r,0.5)
eh_s=5*np.exp(-r/0.5)
es=-0.8 * 1 * (1 + np.tanh(3 * (1.5 - r)))
# plt.plot(r,eh_s,'b-')
plt.plot(r,es+eh_s,'r-')
plt.plot(r,-np.gradient(eh_s+es)/np.gradient(r),'b--')
# plt.plot(r,-np.gradient(es+eh_s)/np.gradient(r),'r--')
plt.ylim(-3,8)
# Out:
# (-3.0, 8.0)

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import numpy as np

# %%
d=np.load('tests/test_out/analyze_traj_testhic.npy')
plt.matshow(d,norm=LogNorm(vmin=1e-4, vmax=0.01))

# %%
b=[[1,2,3],[6,6,2],[52,62,3],[4,234,5],[54232,124,1]]
a=np.array(b)
print(a)
# Out:
# [[    1     2     3]
#  [    6     6     2]
#  [   52    62     3]
#  [    4   234     5]
#  [54232   124     1]]

# %%
traj=np.load('../../data/trajectory/sample_traj_Rouse_chain_T0.5_F0.0_Ta1.0_Esoft0_R0100_Na1200_blocksize100_kb5.0_dt0.001_kr30.0_positions.npy')

# %%
1200/(8*20**3)
# Out:
# 0.01875

# %%
trajA,trajB=[],[]
for ii,line in enumerate(open('../sim_codes/input_files/chr_seq.txt')):
    print(line.split())
    if 'A' in line:
        trajA.append(traj[:,ii,:])
    elif 'B' in line:
        trajB.append(traj[:,ii,:])

trajA=np.array(trajA)
trajB=np.array(trajB)

na=trajA.shape[0]
nb=trajB.shape[0]

trajA=trajA.reshape(traj.shape[0],na,3)
trajB=trajB.reshape(traj.shape[0],nb,3)

print(trajA.shape, trajB.shape)
# Out:
# ['1', 'B']
# ['2', 'B']
# ['3', 'B']
# ['4', 'A']
# ['5', 'B']
# ['6', 'A']
# ['7', 'B']
# ['8', 'B']
# ['9', 'A']
# ['10', 'A']
# ['11', 'A']
# ['12', 'A']
# ['13', 'B']
# ['14', 'A']
# ['15', 'A']
# ['16', 'A']
# ['17', 'A']
# ['18', 'B']
# ['19', 'A']
# ['20', 'B']
# ['21', 'A']
# ['22', 'A']
# ['23', 'B']
# ['24', 'B']
# ['25', 'B']
# ['26', 'A']
# ['27', 'B']
# ['28', 'A']
# ['29', 'A']
# ['30', 'A']
# ['31', 'A']
# ['32', 'A']
# ['33', 'B']
# ['34', 'A']
# ['35', 'B']
# ['36', 'A']
# ['37', 'A']
# ['38', 'B']
# ['39', 'B']
# ['40', 'B']
# ['41', 'A']
# ['42', 'A']
# ['43', 'A']
# ['44', 'B']
# ['45', 'A']
# ['46', 'B']
# ['47', 'A']
# ['48', 'A']
# ['49', 'B']
# ['50', 'A']
# ['51', 'B']
# ['52', 'A']
# ['53', 'B']
# ['54', 'A']
# ['55', 'B']
# ['56', 'B']
# ['57', 'A']
# ['58', 'B']
# ['59', 'B']
# ['60', 'A']
# ['61', 'A']
# ['62', 'A']
# ['63', 'B']
# ['64', 'B']
# ['65', 'A']
# ['66', 'A']
# ['67', 'B']
# ['68', 'B']
# ['69', 'A']
# ['70', 'A']
# ['71', 'B']
# ['72', 'B']
# ['73', 'A']
# ['74', 'B']
# ['75', 'A']
# ['76', 'B']
# ['77', 'B']
# ['78', 'B']
# ['79', 'A']
# ['80', 'B']
# ['81', 'A']
# ['82', 'B']
# ['83', 'A']
# ['84', 'B']
# ['85', 'A']
# ['86', 'A']
# ['87', 'A']
# ['88', 'B']
# ['89', 'B']
# ['90', 'B']
# ['91', 'B']
# ['92', 'A']
# ['93', 'B']
# ['94', 'A']
# ['95', 'A']
# ['96', 'B']
# ['97', 'A']
# ['98', 'A']
# ['99', 'A']
# ['100', 'A']
# ['101', 'A']
# ['102', 'A']
# ['103', 'A']
# ['104', 'B']
# ['105', 'A']
# ['106', 'A']
# ['107', 'A']
# ['108', 'A']
# ['109', 'A']
# ['110', 'B']
# ['111', 'A']
# ['112', 'B']
# ['113', 'A']
# ['114', 'A']
# ['115', 'A']
# ['116', 'A']
# ['117', 'B']
# ['118', 'B']
# ['119', 'A']
# ['120', 'B']
# ['121', 'A']
# ['122', 'A']
# ['123', 'B']
# ['124', 'A']
# ['125', 'B']
# ['126', 'A']
# ['127', 'B']
# ['128', 'B']
# ['129', 'A']
# ['130', 'B']
# ['131', 'B']
# ['132', 'B']
# ['133', 'A']
# ['134', 'A']
# ['135', 'A']
# ['136', 'A']
# ['137', 'B']
# ['138', 'A']
# ['139', 'A']
# ['140', 'B']
# ['141', 'B']
# ['142', 'A']
# ['143', 'B']
# ['144', 'A']
# ['145', 'A']
# ['146', 'B']
# ['147', 'A']
# ['148', 'B']
# ['149', 'A']
# ['150', 'B']
# ['151', 'A']
# ['152', 'B']
# ['153', 'A']
# ['154', 'A']
# ['155', 'B']
# ['156', 'A']
# ['157', 'B']
# ['158', 'B']
# ['159', 'B']
# ['160', 'B']
# ['161', 'B']
# ['162', 'B']
# ['163', 'A']
# ['164', 'B']
# ['165', 'A']
# ['166', 'A']
# ['167', 'B']
# ['168', 'B']
# ['169', 'A']
# ['170', 'B']
# ['171', 'A']
# ['172', 'A']
# ['173', 'B']
# ['174', 'A']
# ['175', 'A']
# ['176', 'B']
# ['177', 'B']
# ['178', 'B']
# ['179', 'B']
# ['180', 'A']
# ['181', 'A']
# ['182', 'A']
# ['183', 'B']
# ['184', 'A']
# ['185', 'B']
# ['186', 'B']
# ['187', 'A']
# ['188', 'B']
# ['189', 'A']
# ['190', 'A']
# ['191', 'A']
# ['192', 'A']
# ['193', 'B']
# ['194', 'A']
# ['195', 'B']
# ['196', 'B']
# ['197', 'B']
# ['198', 'B']
# ['199', 'A']
# ['200', 'A']
# ['201', 'A']
# ['202', 'B']
# ['203', 'B']
# ['204', 'A']
# ['205', 'B']
# ['206', 'A']
# ['207', 'B']
# ['208', 'A']
# ['209', 'B']
# ['210', 'A']
# ['211', 'B']
# ['212', 'B']
# ['213', 'A']
# ['214', 'A']
# ['215', 'B']
# ['216', 'A']
# ['217', 'B']
# ['218', 'B']
# ['219', 'A']
# ['220', 'B']
# ['221', 'B']
# ['222', 'B']
# ['223', 'A']
# ['224', 'B']
# ['225', 'A']
# ['226', 'B']
# ['227', 'A']
# ['228', 'B']
# ['229', 'A']
# ['230', 'B']
# ['231', 'B']
# ['232', 'A']
# ['233', 'A']
# ['234', 'A']
# ['235', 'B']
# ['236', 'A']
# ['237', 'B']
# ['238', 'A']
# ['239', 'B']
# ['240', 'A']
# ['241', 'A']
# ['242', 'A']
# ['243', 'A']
# ['244', 'B']
# ['245', 'A']
# ['246', 'A']
# ['247', 'A']
# ['248', 'B']
# ['249', 'A']
# ['250', 'B']
# ['251', 'B']
# ['252', 'A']
# ['253', 'B']
# ['254', 'A']
# ['255', 'B']
# ['256', 'B']
# ['257', 'B']
# ['258', 'A']
# ['259', 'A']
# ['260', 'A']
# ['261', 'A']
# ['262', 'B']
# ['263', 'B']
# ['264', 'A']
# ['265', 'B']
# ['266', 'A']
# ['267', 'B']
# ['268', 'B']
# ['269', 'B']
# ['270', 'B']
# ['271', 'B']
# ['272', 'A']
# ['273', 'B']
# ['274', 'A']
# ['275', 'B']
# ['276', 'A']
# ['277', 'A']
# ['278', 'A']
# ['279', 'A']
# ['280', 'A']
# ['281', 'B']
# ['282', 'A']
# ['283', 'A']
# ['284', 'A']
# ['285', 'A']
# ['286', 'B']
# ['287', 'A']
# ['288', 'A']
# ['289', 'A']
# ['290', 'B']
# ['291', 'A']
# ['292', 'B']
# ['293', 'B']
# ['294', 'B']
# ['295', 'B']
# ['296', 'A']
# ['297', 'A']
# ['298', 'A']
# ['299', 'B']
# ['300', 'A']
# ['301', 'B']
# ['302', 'B']
# ['303', 'A']
# ['304', 'A']
# ['305', 'B']
# ['306', 'B']
# ['307', 'B']
# ['308', 'B']
# ['309', 'B']
# ['310', 'A']
# ['311', 'B']
# ['312', 'A']
# ['313', 'A']
# ['314', 'A']
# ['315', 'B']
# ['316', 'B']
# ['317', 'A']
# ['318', 'A']
# ['319', 'B']
# ['320', 'B']
# ['321', 'A']
# ['322', 'A']
# ['323', 'A']
# ['324', 'A']
# ['325', 'A']
# ['326', 'B']
# ['327', 'B']
# ['328', 'B']
# ['329', 'B']
# ['330', 'B']
# ['331', 'A']
# ['332', 'B']
# ['333', 'A']
# ['334', 'B']
# ['335', 'B']
# ['336', 'B']
# ['337', 'B']
# ['338', 'A']
# ['339', 'A']
# ['340', 'A']
# ['341', 'A']
# ['342', 'B']
# ['343', 'A']
# ['344', 'A']
# ['345', 'B']
# ['346', 'A']
# ['347', 'A']
# ['348', 'B']
# ['349', 'A']
# ['350', 'A']
# ['351', 'B']
# ['352', 'B']
# ['353', 'B']
# ['354', 'B']
# ['355', 'A']
# ['356', 'A']
# ['357', 'B']
# ['358', 'A']
# ['359', 'B']
# ['360', 'A']
# ['361', 'A']
# ['362', 'A']
# ['363', 'B']
# ['364', 'A']
# ['365', 'A']
# ['366', 'A']
# ['367', 'B']
# ['368', 'A']
# ['369', 'A']
# ['370', 'B']
# ['371', 'B']
# ['372', 'B']
# ['373', 'A']
# ['374', 'A']
# ['375', 'A']
# ['376', 'A']
# ['377', 'A']
# ['378', 'B']
# ['379', 'B']
# ['380', 'A']
# ['381', 'A']
# ['382', 'B']
# ['383', 'B']
# ['384', 'A']
# ['385', 'B']
# ['386', 'A']
# ['387', 'A']
# ['388', 'B']
# ['389', 'B']
# ['390', 'A']
# ['391', 'A']
# ['392', 'A']
# ['393', 'A']
# ['394', 'A']
# ['395', 'B']
# ['396', 'A']
# ['397', 'A']
# ['398', 'A']
# ['399', 'A']
# ['400', 'A']
# ['401', 'B']
# ['402', 'A']
# ['403', 'A']
# ['404', 'B']
# ['405', 'A']
# ['406', 'B']
# ['407', 'B']
# ['408', 'A']
# ['409', 'B']
# ['410', 'B']
# ['411', 'A']
# ['412', 'A']
# ['413', 'A']
# ['414', 'B']
# ['415', 'A']
# ['416', 'A']
# ['417', 'A']
# ['418', 'A']
# ['419', 'B']
# ['420', 'A']
# ['421', 'B']
# ['422', 'A']
# ['423', 'B']
# ['424', 'A']
# ['425', 'B']
# ['426', 'A']
# ['427', 'B']
# ['428', 'B']
# ['429', 'B']
# ['430', 'B']
# ['431', 'A']
# ['432', 'A']
# ['433', 'B']
# ['434', 'B']
# ['435', 'A']
# ['436', 'A']
# ['437', 'B']
# ['438', 'B']
# ['439', 'B']
# ['440', 'A']
# ['441', 'A']
# ['442', 'A']
# ['443', 'B']
# ['444', 'A']
# ['445', 'B']
# ['446', 'B']
# ['447', 'A']
# ['448', 'A']
# ['449', 'A']
# ['450', 'B']
# ['451', 'A']
# ['452', 'A']
# ['453', 'B']
# ['454', 'B']
# ['455', 'B']
# ['456', 'B']
# ['457', 'A']
# ['458', 'A']
# ['459', 'A']
# ['460', 'A']
# ['461', 'A']
# ['462', 'A']
# ['463', 'A']
# ['464', 'A']
# ['465', 'B']
# ['466', 'A']
# ['467', 'A']
# ['468', 'A']
# ['469', 'A']
# ['470', 'A']
# ['471', 'A']
# ['472', 'B']
# ['473', 'B']
# ['474', 'A']
# ['475', 'A']
# ['476', 'A']
# ['477', 'B']
# ['478', 'A']
# ['479', 'A']
# ['480', 'A']
# ['481', 'B']
# ['482', 'B']
# ['483', 'A']
# ['484', 'A']
# ['485', 'B']
# ['486', 'A']
# ['487', 'A']
# ['488', 'B']
# ['489', 'A']
# ['490', 'A']
# ['491', 'B']
# ['492', 'A']
# ['493', 'B']
# ['494', 'A']
# ['495', 'A']
# ['496', 'B']
# ['497', 'A']
# ['498', 'A']
# ['499', 'B']
# ['500', 'A']
# ['501', 'B']
# ['502', 'A']
# ['503', 'A']
# ['504', 'A']
# ['505', 'B']
# ['506', 'B']
# ['507', 'B']
# ['508', 'B']
# ['509', 'B']
# ['510', 'A']
# ['511', 'B']
# ['512', 'A']
# ['513', 'A']
# ['514', 'A']
# ['515', 'A']
# ['516', 'B']
# ['517', 'B']
# ['518', 'A']
# ['519', 'B']
# ['520', 'A']
# ['521', 'B']
# ['522', 'A']
# ['523', 'B']
# ['524', 'B']
# ['525', 'A']
# ['526', 'A']
# ['527', 'B']
# ['528', 'B']
# ['529', 'A']
# ['530', 'A']
# ['531', 'A']
# ['532', 'A']
# ['533', 'A']
# ['534', 'B']
# ['535', 'A']
# ['536', 'B']
# ['537', 'A']
# ['538', 'B']
# ['539', 'A']
# ['540', 'A']
# ['541', 'B']
# ['542', 'A']
# ['543', 'B']
# ['544', 'A']
# ['545', 'A']
# ['546', 'B']
# ['547', 'B']
# ['548', 'B']
# ['549', 'B']
# ['550', 'B']
# ['551', 'B']
# ['552', 'B']
# ['553', 'A']
# ['554', 'B']
# ['555', 'B']
# ['556', 'B']
# ['557', 'A']
# ['558', 'B']
# ['559', 'A']
# ['560', 'B']
# ['561', 'B']
# ['562', 'B']
# ['563', 'B']
# ['564', 'A']
# ['565', 'A']
# ['566', 'B']
# ['567', 'B']
# ['568', 'B']
# ['569', 'B']
# ['570', 'B']
# ['571', 'B']
# ['572', 'A']
# ['573', 'B']
# ['574', 'A']
# ['575', 'A']
# ['576', 'B']
# ['577', 'A']
# ['578', 'B']
# ['579', 'A']
# ['580', 'B']
# ['581', 'B']
# ['582', 'B']
# ['583', 'B']
# ['584', 'A']
# ['585', 'B']
# ['586', 'A']
# ['587', 'A']
# ['588', 'B']
# ['589', 'A']
# ['590', 'B']
# ['591', 'A']
# ['592', 'B']
# ['593', 'B']
# ['594', 'A']
# ['595', 'A']
# ['596', 'A']
# ['597', 'B']
# ['598', 'B']
# ['599', 'A']
# ['600', 'A']
# ['601', 'A']
# ['602', 'A']
# ['603', 'B']
# ['604', 'B']
# ['605', 'A']
# ['606', 'A']
# ['607', 'B']
# ['608', 'A']
# ['609', 'A']
# ['610', 'A']
# ['611', 'A']
# ['612', 'B']
# ['613', 'B']
# ['614', 'B']
# ['615', 'B']
# ['616', 'A']
# ['617', 'A']
# ['618', 'A']
# ['619', 'A']
# ['620', 'B']
# ['621', 'A']
# ['622', 'B']
# ['623', 'A']
# ['624', 'A']
# ['625', 'A']
# ['626', 'B']
# ['627', 'A']
# ['628', 'B']
# ['629', 'A']
# ['630', 'A']
# ['631', 'A']
# ['632', 'A']
# ['633', 'B']
# ['634', 'B']
# ['635', 'A']
# ['636', 'A']
# ['637', 'A']
# ['638', 'A']
# ['639', 'B']
# ['640', 'A']
# ['641', 'B']
# ['642', 'A']
# ['643', 'A']
# ['644', 'A']
# ['645', 'A']
# ['646', 'A']
# ['647', 'B']
# ['648', 'A']
# ['649', 'B']
# ['650', 'A']
# ['651', 'A']
# ['652', 'B']
# ['653', 'A']
# ['654', 'A']
# ['655', 'A']
# ['656', 'A']
# ['657', 'A']
# ['658', 'B']
# ['659', 'A']
# ['660', 'A']
# ['661', 'B']
# ['662', 'A']
# ['663', 'B']
# ['664', 'B']
# ['665', 'B']
# ['666', 'A']
# ['667', 'A']
# ['668', 'B']
# ['669', 'B']
# ['670', 'B']
# ['671', 'B']
# ['672', 'B']
# ['673', 'B']
# ['674', 'B']
# ['675', 'B']
# ['676', 'A']
# ['677', 'B']
# ['678', 'A']
# ['679', 'A']
# ['680', 'B']
# ['681', 'A']
# ['682', 'A']
# ['683', 'B']
# ['684', 'B']
# ['685', 'A']
# ['686', 'A']
# ['687', 'A']
# ['688', 'A']
# ['689', 'B']
# ['690', 'A']
# ['691', 'A']
# ['692', 'A']
# ['693', 'B']
# ['694', 'A']
# ['695', 'A']
# ['696', 'B']
# ['697', 'A']
# ['698', 'A']
# ['699', 'B']
# ['700', 'A']
# ['701', 'B']
# ['702', 'B']
# ['703', 'A']
# ['704', 'A']
# ['705', 'B']
# ['706', 'A']
# ['707', 'A']
# ['708', 'B']
# ['709', 'B']
# ['710', 'B']
# ['711', 'A']
# ['712', 'A']
# ['713', 'A']
# ['714', 'A']
# ['715', 'B']
# ['716', 'A']
# ['717', 'B']
# ['718', 'B']
# ['719', 'A']
# ['720', 'B']
# ['721', 'B']
# ['722', 'A']
# ['723', 'B']
# ['724', 'A']
# ['725', 'A']
# ['726', 'A']
# ['727', 'B']
# ['728', 'B']
# ['729', 'B']
# ['730', 'A']
# ['731', 'B']
# ['732', 'B']
# ['733', 'A']
# ['734', 'B']
# ['735', 'A']
# ['736', 'A']
# ['737', 'B']
# ['738', 'A']
# ['739', 'A']
# ['740', 'B']
# ['741', 'A']
# ['742', 'B']
# ['743', 'B']
# ['744', 'B']
# ['745', 'A']
# ['746', 'A']
# ['747', 'B']
# ['748', 'A']
# ['749', 'A']
# ['750', 'A']
# ['751', 'A']
# ['752', 'B']
# ['753', 'A']
# ['754', 'A']
# ['755', 'B']
# ['756', 'B']
# ['757', 'B']
# ['758', 'B']
# ['759', 'B']
# ['760', 'A']
# ['761', 'B']
# ['762', 'B']
# ['763', 'B']
# ['764', 'B']
# ['765', 'A']
# ['766', 'A']
# ['767', 'B']
# ['768', 'A']
# ['769', 'B']
# ['770', 'B']
# ['771', 'B']
# ['772', 'B']
# ['773', 'B']
# ['774', 'B']
# ['775', 'A']
# ['776', 'B']
# ['777', 'A']
# ['778', 'B']
# ['779', 'A']
# ['780', 'B']
# ['781', 'B']
# ['782', 'A']
# ['783', 'B']
# ['784', 'B']
# ['785', 'A']
# ['786', 'A']
# ['787', 'A']
# ['788', 'B']
# ['789', 'B']
# ['790', 'B']
# ['791', 'B']
# ['792', 'A']
# ['793', 'B']
# ['794', 'B']
# ['795', 'B']
# ['796', 'A']
# ['797', 'A']
# ['798', 'B']
# ['799', 'B']
# ['800', 'B']
# ['801', 'B']
# ['802', 'B']
# ['803', 'A']
# ['804', 'B']
# ['805', 'A']
# ['806', 'B']
# ['807', 'A']
# ['808', 'A']
# ['809', 'A']
# ['810', 'A']
# ['811', 'A']
# ['812', 'B']
# ['813', 'A']
# ['814', 'B']
# ['815', 'A']
# ['816', 'A']
# ['817', 'A']
# ['818', 'B']
# ['819', 'B']
# ['820', 'B']
# ['821', 'B']
# ['822', 'B']
# ['823', 'B']
# ['824', 'B']
# ['825', 'A']
# ['826', 'B']
# ['827', 'A']
# ['828', 'B']
# ['829', 'B']
# ['830', 'B']
# ['831', 'A']
# ['832', 'B']
# ['833', 'A']
# ['834', 'B']
# ['835', 'B']
# ['836', 'B']
# ['837', 'A']
# ['838', 'A']
# ['839', 'A']
# ['840', 'B']
# ['841', 'A']
# ['842', 'A']
# ['843', 'A']
# ['844', 'A']
# ['845', 'B']
# ['846', 'A']
# ['847', 'B']
# ['848', 'A']
# ['849', 'A']
# ['850', 'B']
# ['851', 'B']
# ['852', 'A']
# ['853', 'A']
# ['854', 'B']
# ['855', 'A']
# ['856', 'A']
# ['857', 'B']
# ['858', 'B']
# ['859', 'A']
# ['860', 'B']
# ['861', 'B']
# ['862', 'A']
# ['863', 'A']
# ['864', 'B']
# ['865', 'B']
# ['866', 'B']
# ['867', 'A']
# ['868', 'B']
# ['869', 'A']
# ['870', 'A']
# ['871', 'B']
# ['872', 'B']
# ['873', 'A']
# ['874', 'A']
# ['875', 'A']
# ['876', 'B']
# ['877', 'B']
# ['878', 'A']
# ['879', 'A']
# ['880', 'B']
# ['881', 'A']
# ['882', 'B']
# ['883', 'B']
# ['884', 'A']
# ['885', 'A']
# ['886', 'A']
# ['887', 'B']
# ['888', 'B']
# ['889', 'A']
# ['890', 'A']
# ['891', 'B']
# ['892', 'B']
# ['893', 'A']
# ['894', 'B']
# ['895', 'B']
# ['896', 'A']
# ['897', 'B']
# ['898', 'A']
# ['899', 'B']
# ['900', 'B']
# ['901', 'A']
# ['902', 'B']
# ['903', 'A']
# ['904', 'A']
# ['905', 'A']
# ['906', 'A']
# ['907', 'B']
# ['908', 'B']
# ['909', 'B']
# ['910', 'A']
# ['911', 'B']
# ['912', 'A']
# ['913', 'A']
# ['914', 'B']
# ['915', 'A']
# ['916', 'A']
# ['917', 'B']
# ['918', 'B']
# ['919', 'A']
# ['920', 'B']
# ['921', 'A']
# ['922', 'B']
# ['923', 'A']
# ['924', 'B']
# ['925', 'B']
# ['926', 'B']
# ['927', 'B']
# ['928', 'A']
# ['929', 'B']
# ['930', 'B']
# ['931', 'A']
# ['932', 'A']
# ['933', 'A']
# ['934', 'A']
# ['935', 'A']
# ['936', 'A']
# ['937', 'A']
# ['938', 'B']
# ['939', 'B']
# ['940', 'A']
# ['941', 'A']
# ['942', 'A']
# ['943', 'A']
# ['944', 'A']
# ['945', 'A']
# ['946', 'B']
# ['947', 'B']
# ['948', 'B']
# ['949', 'A']
# ['950', 'A']
# ['951', 'B']
# ['952', 'B']
# ['953', 'A']
# ['954', 'B']
# ['955', 'A']
# ['956', 'B']
# ['957', 'A']
# ['958', 'A']
# ['959', 'A']
# ['960', 'A']
# ['961', 'A']
# ['962', 'A']
# ['963', 'B']
# ['964', 'B']
# ['965', 'A']
# ['966', 'A']
# ['967', 'A']
# ['968', 'B']
# ['969', 'A']
# ['970', 'B']
# ['971', 'A']
# ['972', 'B']
# ['973', 'A']
# ['974', 'B']
# ['975', 'A']
# ['976', 'B']
# ['977', 'B']
# ['978', 'A']
# ['979', 'A']
# ['980', 'A']
# ['981', 'B']
# ['982', 'A']
# ['983', 'B']
# ['984', 'B']
# ['985', 'B']
# ['986', 'B']
# ['987', 'B']
# ['988', 'B']
# ['989', 'A']
# ['990', 'B']
# ['991', 'A']
# ['992', 'A']
# ['993', 'B']
# ['994', 'B']
# ['995', 'A']
# ['996', 'B']
# ['997', 'A']
# ['998', 'B']
# ['999', 'A']
# ['1000', 'B']
# ['1001', 'A']
# ['1002', 'A']
# ['1003', 'A']
# ['1004', 'A']
# ['1005', 'B']
# ['1006', 'A']
# ['1007', 'A']
# ['1008', 'A']
# ['1009', 'A']
# ['1010', 'A']
# ['1011', 'B']
# ['1012', 'B']
# ['1013', 'B']
# ['1014', 'A']
# ['1015', 'A']
# ['1016', 'A']
# ['1017', 'B']
# ['1018', 'A']
# ['1019', 'B']
# ['1020', 'B']
# ['1021', 'B']
# ['1022', 'B']
# ['1023', 'B']
# ['1024', 'A']
# ['1025', 'B']
# ['1026', 'B']
# ['1027', 'A']
# ['1028', 'A']
# ['1029', 'A']
# ['1030', 'B']
# ['1031', 'A']
# ['1032', 'B']
# ['1033', 'A']
# ['1034', 'B']
# ['1035', 'B']
# ['1036', 'A']
# ['1037', 'B']
# ['1038', 'B']
# ['1039', 'A']
# ['1040', 'A']
# ['1041', 'B']
# ['1042', 'A']
# ['1043', 'A']
# ['1044', 'A']
# ['1045', 'B']
# ['1046', 'B']
# ['1047', 'A']
# ['1048', 'B']
# ['1049', 'B']
# ['1050', 'A']
# ['1051', 'B']
# ['1052', 'A']
# ['1053', 'B']
# ['1054', 'B']
# ['1055', 'B']
# ['1056', 'B']
# ['1057', 'B']
# ['1058', 'A']
# ['1059', 'B']
# ['1060', 'A']
# ['1061', 'B']
# ['1062', 'A']
# ['1063', 'A']
# ['1064', 'A']
# ['1065', 'A']
# ['1066', 'B']
# ['1067', 'B']
# ['1068', 'A']
# ['1069', 'A']
# ['1070', 'A']
# ['1071', 'A']
# ['1072', 'A']
# ['1073', 'A']
# ['1074', 'B']
# ['1075', 'A']
# ['1076', 'A']
# ['1077', 'A']
# ['1078', 'B']
# ['1079', 'A']
# ['1080', 'B']
# ['1081', 'B']
# ['1082', 'B']
# ['1083', 'B']
# ['1084', 'B']
# ['1085', 'A']
# ['1086', 'B']
# ['1087', 'A']
# ['1088', 'A']
# ['1089', 'B']
# ['1090', 'A']
# ['1091', 'B']
# ['1092', 'A']
# ['1093', 'B']
# ['1094', 'A']
# ['1095', 'B']
# ['1096', 'A']
# ['1097', 'A']
# ['1098', 'A']
# ['1099', 'B']
# ['1100', 'B']
# ['1101', 'B']
# ['1102', 'B']
# ['1103', 'B']
# ['1104', 'A']
# ['1105', 'A']
# ['1106', 'A']
# ['1107', 'A']
# ['1108', 'B']
# ['1109', 'A']
# ['1110', 'A']
# ['1111', 'A']
# ['1112', 'B']
# ['1113', 'B']
# ['1114', 'B']
# ['1115', 'A']
# ['1116', 'A']
# ['1117', 'B']
# ['1118', 'A']
# ['1119', 'B']
# ['1120', 'A']
# ['1121', 'A']
# ['1122', 'A']
# ['1123', 'B']
# ['1124', 'B']
# ['1125', 'B']
# ['1126', 'A']
# ['1127', 'B']
# ['1128', 'B']
# ['1129', 'A']
# ['1130', 'B']
# ['1131', 'A']
# ['1132', 'A']
# ['1133', 'A']
# ['1134', 'B']
# ['1135', 'B']
# ['1136', 'B']
# ['1137', 'B']
# ['1138', 'A']
# ['1139', 'B']
# ['1140', 'A']
# ['1141', 'A']
# ['1142', 'B']
# ['1143', 'B']
# ['1144', 'B']
# ['1145', 'B']
# ['1146', 'B']
# ['1147', 'A']
# ['1148', 'A']
# ['1149', 'A']
# ['1150', 'B']
# ['1151', 'B']
# ['1152', 'B']
# ['1153', 'B']
# ['1154', 'A']
# ['1155', 'B']
# ['1156', 'A']
# ['1157', 'B']
# ['1158', 'B']
# ['1159', 'A']
# ['1160', 'A']
# ['1161', 'A']
# ['1162', 'A']
# ['1163', 'A']
# ['1164', 'A']
# ['1165', 'B']
# ['1166', 'A']
# ['1167', 'A']
# ['1168', 'B']
# ['1169', 'A']
# ['1170', 'A']
# ['1171', 'A']
# ['1172', 'B']
# ['1173', 'A']
# ['1174', 'A']
# ['1175', 'A']
# ['1176', 'B']
# ['1177', 'A']
# ['1178', 'B']
# ['1179', 'B']
# ['1180', 'A']
# ['1181', 'A']
# ['1182', 'B']
# ['1183', 'B']
# ['1184', 'A']
# ['1185', 'B']
# ['1186', 'B']
# ['1187', 'A']
# ['1188', 'B']
# ['1189', 'A']
# ['1190', 'B']
# ['1191', 'B']
# ['1192', 'B']
# ['1193', 'A']
# ['1194', 'B']
# ['1195', 'A']
# ['1196', 'A']
# ['1197', 'A']
# ['1198', 'B']
# ['1199', 'A']
# ['1200', 'A']
# (1000, 634, 3) (1000, 566, 3)

# %%
seq=np.loadtxt('input_files/chromosome_top.txt',ndmin=2)

# %%
seq.shape
# Out:
# (1, 3)
